# %% [markdown]
# # **Desafio Técnico: Estágio em Dados**
# ## RenovaBR

# %%
import pandas as pd

# %%
# mude seu caminho ate o arquivo aqui
PATH_TO_ELEITORADO = "data/eleitorado/perfil_eleitorado_2020.csv"
PATH_TO_RESULTADOS = "data/resultados/SP_turno_1.csv"

# leitura dos arquivos
eleitorado = pd.read_csv(PATH_TO_ELEITORADO, sep=";", encoding="latin1")
resultados = pd.read_csv(PATH_TO_RESULTADOS, sep=";", encoding="latin1")

# %%
eleitorado.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO SG_UF  CD_MUNICIPIO  \
# 0  01/08/2020   08:37:48         2020    SP         70734
# 1  01/08/2020   08:37:48         2020    SP         70734
# 2  01/08/2020   08:37:48         2020    SP         70734
# 3  01/08/2020   08:37:48         2020    SP         70734
# 4  01/08/2020   08:37:48         2020    SP         70734
#
#            NM_MUNICIPIO  CD_MUN_SIT_BIOMETRIA DS_MUN_SIT_BIOMETRIA  NR_ZONA  \
# 0  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 1  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 2  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 3  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
# 4  SÃO BENTO DO SAPUCAÍ                     0        Sem biometria      314
#
#    CD_GENERO  ... CD_ESTADO_CIVIL  DS_ESTADO_CIVIL CD_FAIXA_ETARIA  \
# 0          4  ...               3           CASADO            7074
# ...

# %%
resultados.head()
# Out:
#    DT_GERACAO HH_GERACAO  ANO_ELEICAO  CD_TIPO_ELEICAO    NM_TIPO_ELEICAO  \
# 0  18/11/2020   15:49:53         2020                0  Eleição Ordinária
# 1  18/11/2020   15:49:53         2020                0  Eleição Ordinária
# 2  18/11/2020   15:49:53         2020                0  Eleição Ordinária
# 3  18/11/2020   15:49:53         2020                0  Eleição Ordinária
# 4  18/11/2020   15:49:53         2020                0  Eleição Ordinária
#
#    CD_PLEITO   DT_PLEITO  NR_TURNO  CD_ELEICAO                DS_ELEICAO  ...  \
# 0        304  15/11/2020         1         426  Eleições Municipais 2020  ...
# 1        304  15/11/2020         1         426  Eleições Municipais 2020  ...
# 2        304  15/11/2020         1         426  Eleições Municipais 2020  ...
# 3        304  15/11/2020         1         426  Eleições Municipais 2020  ...
# 4        304  15/11/2020         1         426  Eleições Municipais 2020  ...
#
# ...

# %%
colunas_resultados = ["DT_PLEITO", "SG_UF", "NM_MUNICIPIO", "NR_ZONA", "NR_SECAO", 
                      "NR_LOCAL_VOTACAO", "CD_CARGO_PERGUNTA", "SG_PARTIDO", "QT_APTOS",
                      "CD_TIPO_VOTAVEL", "NM_VOTAVEL", "QT_VOTOS", "QT_ELEITORES_BIOMETRIA_NH"]

resultados[colunas_resultados].head()
# Out:
#     DT_PLEITO SG_UF NM_MUNICIPIO  NR_ZONA  NR_SECAO  NR_LOCAL_VOTACAO  \
# 0  15/11/2020    SP    SÃO PAULO        1         1              1015
# 1  15/11/2020    SP    SÃO PAULO        1         1              1015
# 2  15/11/2020    SP    SÃO PAULO        1         1              1015
# 3  15/11/2020    SP    SÃO PAULO        1         1              1015
# 4  15/11/2020    SP    SÃO PAULO        1         1              1015
#
#    CD_CARGO_PERGUNTA SG_PARTIDO  QT_APTOS  CD_TIPO_VOTAVEL     NM_VOTAVEL  \
# 0                 11     #NULO#       386                2         Branco
# 1                 11         PT       386                1   JILMAR TATTO
# 2                 11       REDE       386                1   MARINA HELOU
# 3                 11        PSB       386                1  MÁRCIO FRANÇA
# 4                 11       PSDB       386                1    BRUNO COVAS
#
#    QT_VOTOS  QT_ELEITORES_BIOMETRIA_NH
# 0         5                          0
# ...

# %%
colunas_eleitorado = ["ANO_ELEICAO", "SG_UF", "NM_MUNICIPIO", "NR_ZONA",
                      "DS_GENERO", "DS_ESTADO_CIVIL", "DS_FAIXA_ETARIA", "DS_GRAU_ESCOLARIDADE",
                      "QT_ELEITORES_PERFIL"]

eleitorado[colunas_eleitorado].head()
# Out:
#    ANO_ELEICAO SG_UF          NM_MUNICIPIO  NR_ZONA DS_GENERO DS_ESTADO_CIVIL  \
# 0         2020    SP  SÃO BENTO DO SAPUCAÍ      314  FEMININO          CASADO
# 1         2020    SP  SÃO BENTO DO SAPUCAÍ      314  FEMININO          CASADO
# 2         2020    SP  SÃO BENTO DO SAPUCAÍ      314  FEMININO          CASADO
# 3         2020    SP  SÃO BENTO DO SAPUCAÍ      314  FEMININO          CASADO
# 4         2020    SP  SÃO BENTO DO SAPUCAÍ      314  FEMININO          CASADO
#
#                   DS_FAIXA_ETARIA           DS_GRAU_ESCOLARIDADE  \
# 0  70 a 74 anos                    ENSINO FUNDAMENTAL INCOMPLETO
# 1  70 a 74 anos                      ENSINO FUNDAMENTAL COMPLETO
# 2  70 a 74 anos                          ENSINO MÉDIO INCOMPLETO
# 3  70 a 74 anos                            ENSINO MÉDIO COMPLETO
# 4  70 a 74 anos                                SUPERIOR COMPLETO
#
#    QT_ELEITORES_PERFIL
# 0                   47
# 1                    5
# 2                    1
# ...
